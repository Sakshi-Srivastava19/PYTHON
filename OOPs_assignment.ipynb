# %% [markdown]
# ![hi](https://prepbytes-misc-images.s3.ap-south-1.amazonaws.com/assets/1675161205978-OOPs%20Concepts%20in%20Python.jpg)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import requests
from io import BytesIO
url = "https://www.google.com/images/branding/googlelogo/1x/googlelogo_color_272x92dp.png"
response = requests.get(url)
img = mpimg.imread(BytesIO(response.content))
plt.imshow(img)
plt.axis('off')  # Hide axes for better viewing
plt.show()

# %%
from IPython.display import Image

# Use the image URL directly
Image("https://substackcdn.com/image/fetch/f_auto,q_auto:good,fl_progressive:steep/https%3A%2F%2Fsubstack-post-media.s3.amazonaws.com%2Fpublic%2Fimages%2F7c56f17b-aaa7-4472-a65f-c7767ec5f243_1412x1062.png")

# %% [markdown]
# # 1) Problem Statement:
# **You work in XYZ Corporation as a Data Analyst. Your corporation has told you to
# work on functions and classes.
# Tasks To Be Performed:**

# %% [markdown]
# **1. Create a function named ‘factor’ that can only accept 1 argument. The function should return the factorial of that number.**

# %%
def factor(n):
    fact=1
    for i in range(1,n+1):
        fact=fact*i
    return fact
num=int(input("enter no"))
factor(num)
# Out:
# enter no 6
# 720

# %% [markdown]
# **2. Create a function named ‘check_string’, the function should accept a string data from the user and the function should check if the user input contains the letter ‘s’ in it. If it contains the letter ‘s’ then print- ‘The string is containing the letter ‘s’’, if not then print- ‘The string doesn’t contain the letter ‘s’’.**

# %%
def check_string(str1):
        if 's' in str1:
            print('The string is containing the letter s')
        else:
            print('The string doesn’t contain the letter s')
s=input("enter any string")
check_string(s)
# Out:
# enter any string sakshi srivastava
# The string is containing the letter s

# %% [markdown]
# **3. Create a class named ‘student’ and inside the class, create a function named ‘fun1’- this method should accept the user defined input and return that value:**
# **a. Create another method named- message() and that method should print the user defined input that we have defined in ‘fun1’.**

# %%
class student:
    def __init__(self):
        self.a=""
    def fun1(self):
        self.a=input("enter something")
        return self.a
    def message(self):
        print('user has input: ',self.a)
obj=student()
obj.fun1()
obj.message()
# Out:
# enter something hey! i am programming
# user has input:  hey! i am programming

# %% [markdown]
# **4. Create a lambda function that should double or multiply the number (that we will be passing in the lambda function) by 2. Store the lambda function in a variable named ‘double_num’.**

# %%
double_num= lambda x:x*2 
no=int(input("enter no to be doubled"))
res= double_num(no)
print(res)
# Out:
# enter no to be doubled 97
# 194

# %% [markdown]
# **5. Take user input string and check whether that string is palindrome or not.**

# %%
s=input("enter any string")
rem=s.replace(" ", "").lower()
a=rem[::-1]
if a==rem:
    print("palindrome")
else:
    print('not palindrome')
# Out:
# enter any string Madam
# palindrome

# %% [markdown]
# # 2) Problem Statement:
# **You work in XYZ Corporation as a Python Developer. Your corporation has told you to work with the methods, and functions in Python**

# %% [markdown]
# **1. Create a class named ‘Super’ and inside that class define a user-defined function named fun1**
# **a. Inside the ‘fun1’ function, pass the message “This is function 1 in the Super class.” in the print statement.**

# %%
class super():
    def fun1(self):
        print('This is function 1 in the Super class')
ob=super()
ob.fun1()
# Out:
# This is function 1 in the Super class

# %% [markdown]
# **2. Create another class named ‘Modified_Super’ and inherit this class from the Super class**
# **a. Inside the Modified_Super class, create a function named ‘fun1’ and pass the following message inside the print statement: ‘This is function 1 in the Modified Super class.’**
# **b. Create another user-defined function named ‘fun2’ and pass the message: ‘This is the 2 nd function from the Modified Super class’ in the print statement.**
# **c. After that, now create an object for the Modified_Super class and call the fun1().**

# %%
class Modified_Super(super):
    def fun1(self):
        print('This is function 1 in the Modified Super class')
    def fun2(self):
        print('This is function 2 in the Modified Super class')
ob=Modified_Super()
ob.fun1()
# Out:
# This is function 1 in the Modified Super class

# %% [markdown]
# **3. Create 2 methods named ‘Hello’. In the 1st Hello method, pass only one argument and pass this message: ‘This function is only having 1 argument’.And in the 2nd Hello method,pass two arguments and pass this message: This function is having 2 arguments.**
# **a. Try to call both the methods and analyze the output of both the methods.**

# %%
class Greet:
    def Hello(self, arg1=None, arg2=None):
        if arg2 is None:
            print("This function is only having 1 argument")
        else:
            print("This function is having 2 arguments")
obj = Greet()
obj.Hello("Hello")
obj.Hello("Hello", "World")
# Out:
# This function is only having 1 argument
# This function is having 2 arguments

# %% [markdown]
# **4. Create a method named ‘Sum’ that can accept multiple user inputs. Now add those user defined input values using for loop and the function should return the addition of the numbers.**

# %% [markdown]
# class cal:
#     def sum(self,*arg):
#      s=0
#      for i in arg:
#         s+=i
#      return s
# obj=cal()
# a=obj.sum(8,0,8)
# print ('the sum is',a)

# %% [markdown]
# **5. Create a class named ‘Encapsulation’:
# a. Inside the class, first create a constructor. Inside the constructor,
# initialize originalValue variable as 10.
# b. After creating the constructor, define a function named ‘Value’ and this
# function should return the variable that we have initialized in the
# constructor.
# c. Now create a 2nd function named setValue, and pass an argument
# named ‘newValue’. The task of this function will be to replace the value of
# the originalValue variable by the value of newValue variable.**

# %%
class Encapsulation:
    def __init__(self):
        self.originalValue=10
    def value(self):
        return self.originalValue
    def setValue(self,newvalue):
        self.originalValue=newvalue
        return newvalue
ob=Encapsulation()
print('originalValue is: ',ob.value())
print('newValue is: ',ob.setValue(45))
# Out:
# originalValue is:  10
# newValue is:  45

# %% [markdown]
# # Problem Statement:
# You work in XYZ Corporation as a Data Analyst. Your corporation has told you to
# work with the inheritance of the classes.

# %% [markdown]
# **1. Create a class named parent_Class and inside the class, initialize a global
# variable num as 10
# a. Create another class named child_Class and this class should be
# inherited from the parent class.
# b. Now create an object for the child_Class and with the help of
# child_Class object, display the value of ‘num’.**

# %%
class parent_Class:
    var=10
class child_Class(parent_Class):
    def display(self):
      pass
obj=child_Class()
print('the value of num is:',child_Class.var)
# Out:
# the value of num is: 10

# %% [markdown]
# **2. Create three classes named A, B and C
# a. Inside the A class, create a constructor. Inside the constructor, initialize
# 2 global variables name and age.
# b. After initializing the global variables inside the constructor, now create a
# function named ‘details’ and that function should return the ‘name’ variable.
# c. Inside the B class, create a constructor. Inside the constructor, initialize 2
# global variables name and id.
# d. After initializing the global variables inside the constructor, now create a
# function named ‘details’ and that function should return the ‘name’ variable.
# e. The C class should inherit from class A, and B. Inside the class C,
# create a constructor, and inside the constructor, call the constructor of
# class A.
# f. Now, create a method inside the class C, as get_details, and this function
# should return the value of name.
# g. Atlast, create an object of class C, and with the help of the object, call
# the get_details().**

# %%
class A:
    def __init__(self):
        self.name="ARUU"
        self.age=30
    def details(self):
        return self.name
class B:
    def __init__(self):
        self.name="SAKSHI"
        self.id=101
    def details(self):
        return self.name
class C(A,B):
    def __init__(self):
        A.__init__(self)
        B.__init__(self)
    def get_details(self):
        return self.name
ob=C()
print('The name from class C is:',ob.get_details())
# Out:
# The name from class C is: SAKSHI

# %% [markdown]
# **3. Create a class named ‘Sub1’, inside the class, generate a user defined
# function named ‘first’ and inside the function, pass the following statement
# in the print()- ‘This is the first function from Sub 1 class’.
# a. Now create another class named ‘Sub2’, and inside the class, create a
# function named ‘second’, and pass the following message in the print()-
# ‘This is the second function from the Sub 2 class’.
# b. After that, create another class named ‘Super’ and inside that class,
# create a method named ‘final’, and pass the below message in the print()-
# ‘This is the final method from the super class’.
# c. Now, create an object for the Super class and call all the 3 user defined
# methods, i.e., first(), second(), and final().**

# %%
class Sub1:
    def first(self):
        print('This is the first function from Sub 1 class')
class Sub2:
    def second(self):
        print('This is the second function from Sub 2 class')
class super(Sub1,Sub2):
    def final(self):
        print('This is the final method from the super class')
o=super()
o.first()
o.second()
o.final()
# Out:
# This is the first function from Sub 1 class
# This is the second function from Sub 2 class
# This is the final method from the super class

# %% [markdown]
# **4. Create a class named ‘Parent’, and inside the class, create a function named ‘fun1’ and pass the following message in the print()- ‘This is the message from the fun1’.**
# **a. Now create a class named ‘Child1’ and inside the class, create a method named ‘fun2’ and pass the following message in the print()- ‘This is the message from the fun2’.**
# **b. After that, create another class named ‘Child2’ and inside the class,
# create a method named ‘fun3’ and pass the following message in the
# print()- ‘This is the message from the fun3’.**
# **c. Now, create an object of Child2 class and with the help of the object, call
# the ‘fun1’ method from the ‘Parent’ class.**

# %%
class Parent:
    def fun1(self):
        print('This is the message from the fun1')
class child1:
    def fun2(self):
        print('This is the message from the fun2')
class child2(Parent):
    def fun3(self):
        print('This is the message from the fun3')
child2 = child2()
child2.fun1()
# Out:
# This is the message from the fun1

# %% [markdown]
# **5. Create a class named ‘Parent’, and inside the class, create a function
# named ‘fun1’ and pass the following message in the print()- ‘This is the
# message from the fun1’.
# a. Now create a class named ‘Child’ and inside the class, create a method
# named ‘fun2’ and pass the following message in the print()- ‘This is the
# message from fun2
# b. After that, create another class named ‘Hybrid’ and inside the class,
# create a method named ‘fun3’ and pass the following message in the
# print()- ‘This is the message from the fun3’.
# c. Now create an object of Hybrid class and with the help of the object, call
# the ‘fun1’, ‘fun2’ and ‘fun3’ methods.**

# %%
class Parent:
    def fun1(self):
        print('This is the message from the fun1')
class child:
    def fun2(self):
        print('This is the message from the fun2')
class hybrid(Parent,child):
    def fun3(self):
        print('This is the message from the fun3')
hyb=hybrid()
hyb.fun1()
hyb.fun2()
hyb.fun3()
# Out:
# This is the message from the fun1
# This is the message from the fun2
# This is the message from the fun3

# %% [markdown]
# # Problem Statement:
# **Consider yourself to be Sam who is a software engineer. He has been asked to
# build an employee management app. You have to use the OOPs concept to build
# a few classes as outlined in the steps below.**

# %% [markdown]
# **1. Create a class named Employee, with a constructor ‘__init__’ method that
# accepts name and salary as parameters and set properties named name
# and salary.
# 2. Define __str__ method in Employee class so that when someone tries to
# print the object the string Name: employee_name, Salary:
# employee_salary is printed with the actual employee name and salary.**

# %%
class Employee:
    def __init__(self):
        self.name=input("Enter name")
        self.salary=int(input("enter salary"))
    def __str__(self):
        print(f"Name is {self.name} and salary is {self.salary}" )
o=Employee()
o.__str__()
# Out:
# Enter name sakshi srv
# enter salary 10000000
# Name is sakshi srv and salary is 10000000

# %% [markdown]
# **3. Create another class named Calculator, with methods to add, subtract,
# multiply and divide two numbers.
# 4. These methods take two numbers as parameters.
# 5. These methods will be called by a method named execute command.
# 6. Execute command takes in 3 parameters command which is string that can
# be either ‘add’, ‘sub’, ‘mul’, ‘div’, and two numbers and it will call the
# appropriate method based on command parameter**

# %%
class calculator:
    def add(self, num1, num2):
        return num1 + num2
    def subtract(self, num1, num2):
        return num1 - num2
    def multiply(self, num1, num2):
        return num1 * num2
    def divide(self, num1, num2):
        if num2 != 0:
            return num1 / num2
        else:
            return "Cannot divide by zero"
    def execute_command(self, command, num1, num2):
        if command == 'add':
            return self.add(num1, num2)
        elif command == 'sub':
            return self.subtract(num1, num2)
        elif command == 'mul':
            return self.multiply(num1, num2)
        elif command == 'div':
            return self.divide(num1, num2)
        else:
            return "Invalid command"
calc = calculator()
while True:
    print("Choose a command:")
    com = input("Enter command (add, sub, mul, div) or 'exit' to quit: ").lower()
    if com == 'exit':
        break
    
    n1 = float(input("Enter the first number: "))
    n2 = float(input("Enter the second number: "))
    
    result = calc.execute_command(com, n1, n2)
    print(f"Result: {result}")
# Out:
# Choose a command:
# Enter command (add, sub, mul, div) or 'exit' to quit:  add
# Enter the first number:  8
# Enter the second number:  6
# Result: 14.0
# Choose a command:
# Enter command (add, sub, mul, div) or 'exit' to quit:  sub
# Enter the first number:  44
# Enter the second number:  9
# Result: 35.0
# Choose a command:
# Enter command (add, sub, mul, div) or 'exit' to quit:  mul
# Enter the first number:  76
# Enter the second number:  9
# Result: 684.0
# Choose a command:
# Enter command (add, sub, mul, div) or 'exit' to quit:  45
# Enter the first number:  8
# Enter the second number:  9
# Result: Invalid command
# Choose a command:
# Enter command (add, sub, mul, div) or 'exit' to quit:  div
# Enter the first number:  81
# Enter the second number:  9
# Result: 9.0
# Choose a command:
# Enter command (add, sub, mul, div) or 'exit' to quit:  div
# Enter the first number:  8
# Enter the second number:  0
# Result: Cannot divide by zero
# Choose a command:
# Enter command (add, sub, mul, div) or 'exit' to quit:  exit

# %% [markdown]
# # QUIZ

# %% [markdown]
# # 1) What is the output of the following code? name,age = "Suresh",29 print(name,age,"is a \"natural\" swimmer")
# a)Suresh 29 is a \natural \swimmer  <br>  b)Suresh 29 is a atural \swimmer<br>   c)Suresh 29 is a natural \swimmer<br>  d)Suresh 29 is a "natural" swimmer <br><br>
#
# **ans=Suresh 29 is a "natural" swimmer**

# %%
name,age = "Suresh",29 
print(name,age,"is a \"natural\" swimmer")
# Out:
# Suresh 29 is a "natural" swimmer

# %% [markdown]
# # 2) What is the output of the following code? a,b,c = 10,20,50 result = (a + b)//c print("The result is {}".format(c))
# The result is 10
# The result is 20
# The result is 50
# The result is 0
# **ans=The result is 50**

# %%
a,b,c = 10,20,50 
result = (a + b)//c 
print("The result is {}".format(c))
# Out:
# The result is 50

# %% [markdown]
# # 3) What is the output of the following code?
# a = [1,2,3,4,5] b = [2,3,4,5,6] print(a[-1],"and",b[len(b)-1])
# 4 and 6 <br> 5 and 6 <br>None of the options <br>4 and 5
# <br>**ans=5 and 6**

# %%
a = [1,2,3,4,5]
b = [2,3,4,5,6]
print(a[-1],"and",b[len(b)-1])
# Out:
# 5 and 6

# %% [markdown]
# # 4) What is the output of the following code?
# a = list(range(0,10,2))
#
# print(a[::-1])
# <br><br>
# [0, 2, 4, 6, 8]<br>
# [10 ,8, 6, 4, 2, 0]<br>
# [8, 6, 4, 2, 0]<br>
# [0, 2, 4, 6, 8, 10]<br>
#
# **ans=[8, 6, 4, 2, 0]**

# %%
a = list(range(0,10,2))

print(a[::-1])
# Out:
# [8, 6, 4, 2, 0]

# %% [markdown]
# # 5) What is the output of the following code?
# A = 10
# B = 20
# if A > 5 & B > 15:
# print("One")
# elif A < 5 & B < 15:
# print("Two")
# else:
# print("None")<br><br>
# None<br>
# NameError<br>
# One<br>
# Two<br>
#
# **ans=none**

# %%
A = 10
B = 20
if A > 5 & B > 15:
 print("One")
elif A < 5 & B < 15:
 print("Two")
else:
 print("None")
# Out:
# None

# %% [markdown]
# # 6) What is the output of the following code?
# A = 2
# B = 10
# if A > 0 and B%A==0:
# print("One", end=",")
# elif B > 5 and B%2 == 1:
# print("Two", end=" ")
# else:
# pass
# <br><br>
# one,two<br>
# No Output<br>
# Two<br>
# One<br>
# **ANS==one**

# %%
A = 2
B = 10
if A > 0 and B%A==0:
    print("One", end=",")
elif B > 5 and B%2 == 1:
    print("Two", end=" ")
else:
 pass
# Out:
# One,

# %% [markdown]
# # 7) What is the output of the following code?
# def func(self):
# if self%2==0:
# return None
# func(10)
# None<br>
# No Output<br>
# “None”<br>
# None of the options<br><br>
# **ans=no otuput**

# %%
def func(self):
    if self%2==0:
        return None

func(10)

# %% [markdown]
# # 8) What is the output of the following code?
# def func(*self):
# for i in self:
# if i in list(range(0,100,10)):
# print("True", end=",")
# else:
# print("False")
# func(10,15)
# <br><br>
# True, False<br>
# False, False<br>
# True, True<br>
# False, True<br>
# **ans=true,false**

# %%
def func(*self):
    for i in self:
        if i in list(range(0,100,10)):
            print("True", end=",")
        else:
            print("False")

func(10,15)
# Out:
# True,False

# %% [markdown]
# # 9) What is the output of the following code?
# class Myclass:
# def __init__(self):
# self.string = "Intellipaat"
# self.number = 2022
# obj = Myclass()
# print(obj.number, obj.string)<br><br>
# 2022 Intellipaat<br>
# Intellipaat, 2022<br>
# Intellipaat 2022<br>
# 2022, Intellipaat<br><br>
# **ans=2022 Intellipaat**

# %%
class Myclass:

 def __init__(self):
     self.string = "Intellipaat"
     self.number = 2022

obj = Myclass()

print(obj.number, obj.string)
# Out:
# 2022 Intellipaat

# %% [markdown]
# # 10) What is the output of the following code?
# class Parent:
# def __init__(self):
#
# self._name = "Levi"
#
# self.__age = 29
#
# class Child(Parent):
#
# def __init__(self):
#
# Parent.__init__(self)
#
# self._name = "Devon"
# self.__age = 28
# def view(self):
# return self.__age
#
# obj = Child()
#
# obj.view()<br><br>
# 29<br>
# 28<br>
# Levi<br>
# Devon<br><br>
# **ans=28**

# %%
class Parent:
    def __init__(self):
        self._name = "Levi"
        self.__age = 29
class Child(Parent):
    def __init__(self):
        Parent.__init__(self)
        self._name = "Devon"
        self.__age = 28
    def view(self):
        return self.__age

obj = Child()

obj.view()
# Out:
# 28
