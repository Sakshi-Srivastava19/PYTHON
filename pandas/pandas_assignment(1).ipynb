# %% [markdown]
# # Problem Statement:
# **You work in XYZ Corporation as a Data Analyst. Your corporation has told you to
# analyze the customer_churn dataset with various functions.<br>
# Tasks To Be Performed:<br>1. Start off by importing the customer_churn.csv file in the jupyter notebook
# and store that in churn DataFrame.**

# %%
import pandas as pd
churn=pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\intellipaat_assignment\customer_churn.csv")
churn.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# **2. From the churn DataFrame, select only 3rd, 7th, 9th, and 20th columns
# and all the rows and store that in a new DataFrame named newCols.**

# %%
newCols=churn.iloc[:,[3,7,9,20]]
newCols
# Out:
#      Partner     MultipleLines OnlineSecurity Churn
# 0        Yes  No phone service             No    No
# 1         No                No            Yes    No
# 2         No                No            Yes   Yes
# 3         No  No phone service            Yes    No
# 4         No                No             No   Yes
# ...      ...               ...            ...   ...
# 7038     Yes               Yes            Yes    No
# 7039     Yes               Yes             No    No
# 7040     Yes  No phone service            Yes    No
# 7041     Yes               Yes             No   Yes
# 7042      No                No            Yes    No
#
# [7043 rows x 4 columns]

# %% [markdown]
# **3. From the original DataFrame, select only the rows from the 200th index till
# the 1000th index(inclusive) column.**

# %%
selected_r=churn.iloc[200:1001,:]
selected_r
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 200   9323-HGFWY  Female              0     Yes         No      27
# 201   8544-GOQSH  Female              0      No         No      14
# 202   3363-DTIVD    Male              0     Yes        Yes      71
# 203   7018-WBJNK    Male              0      No        Yes      13
# 204   9142-KZXOP    Male              0      No         No      44
# ...          ...     ...            ...     ...        ...     ...
# 996   6641-XRPSU  Female              0      No         No      34
# 997   1374-DMZUI  Female              1      No         No       4
# 998   2545-LXYVJ    Male              0     Yes         No      72
# 999   3234-VKACU    Male              0      No         No       2
# 1000  8357-EQXFO  Female              0      No         No       7
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 200           Yes            No     Fiber optic                  Yes  ...
# ...

# %% [markdown]
# **4. Now select the rows from 20th index till 200th index(exclusive),and
# columns from 2nd index till 15th index value.**

# %%
a=churn.iloc[20:200,2:16]
a
# Out:
#      SeniorCitizen Partner Dependents  tenure PhoneService     MultipleLines  \
# 20               1      No         No       1           No  No phone service
# 21               0     Yes         No      12          Yes                No
# 22               0      No         No       1          Yes                No
# 23               0     Yes         No      58          Yes               Yes
# 24               0     Yes        Yes      49          Yes                No
# ..             ...     ...        ...     ...          ...               ...
# 195              0     Yes         No      20          Yes                No
# 196              0     Yes        Yes      24          Yes               Yes
# 197              0      No         No      59          Yes               Yes
# 198              0     Yes        Yes      72          Yes               Yes
# 199              0      No        Yes       1          Yes                No
#
# ...

# %% [markdown]
# **5. Display the top 100 records from the original DataFrame.**

# %%
top100=churn.head(100)
top100
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0   7590-VHVEG  Female              0     Yes         No       1           No
# 1   5575-GNVDE    Male              0      No         No      34          Yes
# 2   3668-QPYBK    Male              0      No         No       2          Yes
# 3   7795-CFOCW    Male              0      No         No      45           No
# 4   9237-HQITU  Female              0      No         No       2          Yes
# ..         ...     ...            ...     ...        ...     ...          ...
# 95  8637-XJIVR  Female              0      No         No      12          Yes
# 96  9803-FTJCG    Male              0     Yes        Yes      71          Yes
# 97  0278-YXOOG    Male              0      No         No       5          Yes
# 98  3212-KXOCR    Male              0      No         No      52          Yes
# 99  4598-XLKNJ  Female              1     Yes         No      25          Yes
#
# ...

# %% [markdown]
# **6. Display the last 10 records from the DataFrame.**

# %%
last10=churn.tail(10)
last10
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7033  9767-FFLEM    Male              0      No         No      38
# 7034  0639-TSIQW  Female              0      No         No      67
# 7035  8456-QDAVC    Male              0      No         No      19
# 7036  7750-EYXWZ  Female              0      No         No      12
# 7037  2569-WGERO  Female              0      No         No      72
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 7033          Yes                No     Fiber optic                   No  ...
# ...

# %% [markdown]
# **7. Display the last record from the DataFrame.**

# %%
last_record=churn.tail(1)
last_record
# Out:
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 7042  3186-AJIEK   Male              0      No         No      66
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 7042          Yes            No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies  Contract  \
# 7042              Yes         Yes         Yes             Yes  Two year
#
#      PaperlessBilling              PaymentMethod MonthlyCharges  TotalCharges  \
# 7042              Yes  Bank transfer (automatic)         105.65        6844.5
#
#      Churn
# 7042    No
#
# [1 rows x 21 columns]

# %% [markdown]
# **8. Now from the churn DataFrame, try to sort the data by the tenure column
# according to the descending order.**

# %%
sort_by_tenure = churn.sort_values(by='tenure', ascending=False)
sort_by_tenure.head()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 1672  4737-AQCPU    Male              0     Yes        Yes      72
# 193   9680-NIAUV  Female              0     Yes        Yes      72
# 4553  5914-XRFQB    Male              0     Yes         No      72
# 483   5168-MQQCA  Female              0     Yes         No      72
# 3266  0464-WJTKO  Female              0     Yes        Yes      72
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 1672          Yes           Yes             DSL                  Yes  ...
# 193           Yes           Yes     Fiber optic                  Yes  ...
# 4553          Yes           Yes     Fiber optic                  Yes  ...
# 483           Yes           Yes     Fiber optic                   No  ...
# 3266          Yes            No              No  No internet service  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# ...

# %% [markdown]
# **9. Fetch all the records that are satisfying the following condition:<br>
# a. Tenure>50 and the gender as ‘Female’<br>
# b. Gender as ‘Male’ and SeniorCitizen as 0<br>
# c. TechSupport as ‘Yes’ and Churn as ‘No’<br>
# d. Contract type as ‘Month-to-month’ and Churn as ‘Yes’**

# %%
c1=churn[(churn["tenure"]>50) & (churn["gender"]=="Female")]
c1.head()
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 15  3655-SNQYZ  Female              0     Yes        Yes      69          Yes
# 16  8191-XWSZG  Female              0      No         No      52          Yes
# 23  3638-WEABW  Female              0     Yes         No      58          Yes
# 30  3841-NFECX  Female              1     Yes         No      71          Yes
# 35  6234-RAAPL  Female              0     Yes        Yes      72          Yes
#
#    MultipleLines InternetService       OnlineSecurity  ...  \
# 15           Yes     Fiber optic                  Yes  ...
# 16            No              No  No internet service  ...
# 23           Yes             DSL                   No  ...
# 30           Yes     Fiber optic                  Yes  ...
# 35           Yes     Fiber optic                  Yes  ...
#
#        DeviceProtection          TechSupport          StreamingTV  \
# 15                  Yes                  Yes                  Yes
# ...

# %%
c2=churn[(churn["gender"]=="Male") & churn["SeniorCitizen"]==0]
c2.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
c3=churn[(churn['TechSupport']=="Yes") & (churn["Churn"]=="No")]
c3.shape
# Out:
# (1734, 21)

# %%
c4=churn[(churn['Contract']=="Month-to-month") & (churn["Churn"]=="Yes")]
c4.shape
# Out:
# (1655, 21)

# %% [markdown]
# **10. Use a for loop to calculate the number of customers that are getting the
# tech support and are male senior citizens.**

# %%
male_senior_count = 0
for index, row in churn.iterrows():
    if row['gender'] == 'Male' and row['SeniorCitizen'] == 1 and row['TechSupport'] == 'Yes':
        male_senior_count += 1
print(f"Number of male senior citizens getting tech support: {male_senior_count}")
# Out:
# Number of male senior citizens getting tech support: 119

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...
